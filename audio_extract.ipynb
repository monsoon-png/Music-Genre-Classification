# %% [markdown]
# #### Step1: Preprocessing
#
# This notebook does the following:
# - Loads and processing the audio files from the GTZAN Dataset
# - Extracts the audio waveform using Librosa
# - Saves the preprocessed data for further feature extraction and model training

# %%
import os
import librosa
import tqdm
import numpy as np

# %% [markdown]
# #### Dataset Folder Structure
# The dataset is organized into folders where each folder is a genre with 100 .wav files each.
# The genres are as follows: Blues,Classical,Country,Disco,Hip-Hop,Jazz,Metal,Pop,Reggae and Rock

# %%
audio_folder = '/Users/aravpatel/iml final/genres'

# %% [markdown]
# Opening the folder to See which files exist

# %%
for file in os.listdir(audio_folder):
        print(file)
# Out:
# pop
# .DS_Store
# metal
# disco
# blues
# reggae
# classical
# rock
# hiphop
# country
# jazz

# %% [markdown]
# Creating a dictionary to store all genere labels

# %%
label = { 
    folder: idx
    for idx, folder in enumerate(
        folder for folder in os.listdir(audio_folder) if not folder.startswith(".")
    )
}
print(label)
# Out:
# {'pop': 0, 'metal': 1, 'disco': 2, 'blues': 3, 'reggae': 4, 'classical': 5, 'rock': 6, 'hiphop': 7, 'country': 8, 'jazz': 9}

# %% [markdown]
# A `.wav` file is a sequence of floating points that represent sound waves. Each data point corresponds to the amplitude of the sound wave at a specific moment, sampled at a specific rate(eg: 22050 Hz)
#
# First We load each file using librosa and store them in Lists

# %%
X = [] #stores the audio series of a song
y = [] #stores the genre
file_names = [] #stores the file name

# Loop through each folder
for folder in os.listdir(audio_folder):
    print(f'Processing folder: {folder}')
    
    # if the folder is valid
    if os.path.isdir(os.path.join(audio_folder, folder)):
        for file in tqdm.tqdm(os.listdir(os.path.join(audio_folder, folder))):
            file_path = os.path.join(audio_folder, folder, file)
        
            data, sr = librosa.load(file_path, sr=22050) #load using librosa, since the data has a sampling rate of 22050
            
            X.append(data)
            y.append(folder)
            file_names.append(file)
            
print("Processing complete")
# Out:
# Processing folder: pop
# 100%|██████████| 100/100 [00:00<00:00, 278.52it/s]
# Processing folder: .DS_Store
# Processing folder: metal
# 100%|██████████| 100/100 [00:00<00:00, 224.52it/s]
# Processing folder: disco
# 100%|██████████| 100/100 [00:00<00:00, 187.47it/s]
# Processing folder: blues
# 100%|██████████| 100/100 [00:00<00:00, 246.08it/s]
# Processing folder: reggae
# 100%|██████████| 100/100 [00:00<00:00, 237.60it/s]
# Processing folder: classical
# 100%|██████████| 100/100 [00:00<00:00, 224.39it/s]
# Processing folder: rock
# 100%|██████████| 100/100 [00:00<00:00, 234.22it/s]
# Processing folder: hiphop
# 100%|██████████| 100/100 [00:00<00:00, 245.57it/s]
# Processing folder: country
# 100%|██████████| 100/100 [00:00<00:00, 217.37it/s]
# Processing folder: jazz
# 100%|██████████| 100/100 [00:00<00:00, 191.44it/s]
# Processing complete

# %% [markdown]
#  Converting X and y into Numpy Arrays

# %%
#check the length of X, y and genre 
print(len(X))
print(len(y))
print(len(file_names))

X = np.array(X, dtype=object)
# Out:
# 1000
# 1000
# 1000

# %% [markdown]
# Checking if the audio files are of the same length

# %%
# Reference length 
reference_length = len(X[0])

# Number of audio files
num_files = len(X)
print(reference_length)
# Check for different lengths
for i in range(num_files):
    if len(X[i]) != reference_length:
        print(f"File {i} has a different length: {len(X[i])}")
# Out:
# 661504
# File 121 has a different length: 661794
# File 123 has a different length: 661794
# File 124 has a different length: 661794
# File 125 has a different length: 661794
# File 126 has a different length: 661794
# File 128 has a different length: 661794
# File 130 has a different length: 661794
# File 132 has a different length: 661794
# File 133 has a different length: 661794
# File 134 has a different length: 661794
# File 135 has a different length: 661794
# File 140 has a different length: 661794
# File 141 has a different length: 661794
# File 142 has a different length: 661794
# File 143 has a different length: 661794
# File 148 has a different length: 661794
# File 149 has a different length: 661794
# File 152 has a different length: 661794
# File 153 has a different length: 661794
# File 156 has a different length: 661794
# File 157 has a different length: 661794
# File 160 has a different length: 661794
# File 161 has a different length: 661794
# File 164 has a different length: 661794
# File 165 has a different length: 661794
# File 168 has a different length: 661794
# File 170 has a different length: 661794
# File 173 has a different length: 661794
# File 174 has a different length: 661794
# File 176 has a different length: 661794
# File 177 has a different length: 661794
# File 179 has a different length: 661794
# File 208 has a different length: 661794
# File 217 has a different length: 661794
# File 219 has a different length: 661794
# File 226 has a different length: 661794
# File 229 has a different length: 661794
# File 234 has a different length: 661794
# File 236 has a different length: 661794
# File 237 has a different length: 661794
# File 238 has a different length: 661794
# File 239 has a different length: 661794
# File 240 has a different length: 661794
# File 241 has a different length: 661794
# File 242 has a different length: 661794
# File 243 has a different length: 661794
# File 244 has a different length: 661794
# File 245 has a different length: 661794
# File 246 has a different length: 661794
# File 247 has a different length: 661794
# File 248 has a different length: 661794
# File 249 has a different length: 661794
# File 250 has a different length: 665060
# File 251 has a different length: 661794
# File 252 has a different length: 661794
# File 253 has a different length: 661794
# File 254 has a different length: 661794
# File 255 has a different length: 661794
# File 256 has a different length: 661760
# File 257 has a different length: 661794
# File 258 has a different length: 661794
# File 259 has a different length: 661794
# File 260 has a different length: 667920
# File 261 has a different length: 661794
# File 262 has a different length: 661794
# File 263 has a different length: 661794
# File 264 has a different length: 663520
# File 265 has a different length: 661676
# File 266 has a different length: 661794
# File 267 has a different length: 667920
# File 268 has a different length: 661794
# File 269 has a different length: 668140
# File 270 has a different length: 661794
# File 271 has a different length: 661794
# File 272 has a different length: 666160
# File 273 has a different length: 664180
# File 274 has a different length: 661344
# File 275 has a different length: 661794
# File 300 has a different length: 661794
# File 301 has a different length: 661794
# File 302 has a different length: 661794
# File 303 has a different length: 661794
# File 304 has a different length: 661794
# File 305 has a different length: 661794
# File 306 has a different length: 661794
# File 307 has a different length: 661794
# File 308 has a different length: 661794
# File 309 has a different length: 661794
# File 310 has a different length: 661794
# File 311 has a different length: 661794
# File 312 has a different length: 661794
# File 313 has a different length: 661794
# File 314 has a different length: 661794
# File 315 has a different length: 661794
# File 316 has a different length: 661794
# File 317 has a different length: 661794
# File 318 has a different length: 661794
# File 319 has a different length: 661794
# File 320 has a different length: 661794
# File 321 has a different length: 661794
# File 322 has a different length: 661794
# File 323 has a different length: 661794
# File 324 has a different length: 661794
# File 325 has a different length: 661794
# File 326 has a different length: 661794
# File 327 has a different length: 661794
# File 328 has a different length: 661794
# File 329 has a different length: 661794
# File 330 has a different length: 661794
# File 331 has a different length: 661794
# File 332 has a different length: 661794
# File 333 has a different length: 661794
# File 334 has a different length: 661794
# File 335 has a different length: 661794
# File 336 has a different length: 661794
# File 337 has a different length: 661794
# File 338 has a different length: 661794
# File 339 has a different length: 661794
# File 340 has a different length: 661794
# File 341 has a different length: 661794
# File 342 has a different length: 661794
# File 343 has a different length: 661794
# File 344 has a different length: 661794
# File 345 has a different length: 661794
# File 346 has a different length: 661794
# File 347 has a different length: 661794
# File 348 has a different length: 661794
# File 349 has a different length: 661794
# File 350 has a different length: 661794
# File 351 has a different length: 661794
# File 352 has a different length: 661794
# File 353 has a different length: 661794
# File 354 has a different length: 661794
# File 355 has a different length: 661794
# File 356 has a different length: 661794
# File 357 has a different length: 661794
# File 358 has a different length: 661794
# File 359 has a different length: 661794
# File 360 has a different length: 661794
# File 361 has a different length: 661794
# File 362 has a different length: 661794
# File 363 has a different length: 661794
# File 364 has a different length: 661794
# File 365 has a different length: 661794
# File 366 has a different length: 661794
# File 367 has a different length: 661794
# File 368 has a different length: 661794
# File 369 has a different length: 661794
# File 370 has a different length: 661794
# File 371 has a different length: 661794
# File 372 has a different length: 661794
# File 373 has a different length: 661794
# File 374 has a different length: 661794
# File 375 has a different length: 661794
# File 376 has a different length: 661794
# File 377 has a different length: 661794
# File 378 has a different length: 661794
# File 379 has a different length: 661794
# File 380 has a different length: 661794
# File 381 has a different length: 661794
# File 382 has a different length: 661794
# File 383 has a different length: 661794
# File 384 has a different length: 661794
# File 385 has a different length: 661794
# File 386 has a different length: 661794
# File 387 has a different length: 661794
# File 388 has a different length: 661794
# File 389 has a different length: 661794
# File 390 has a different length: 661794
# File 391 has a different length: 661794
# File 392 has a different length: 661794
# File 393 has a different length: 661794
# File 394 has a different length: 661794
# File 395 has a different length: 661794
# File 396 has a different length: 661794
# File 397 has a different length: 661794
# File 398 has a different length: 661794
# File 399 has a different length: 661794
# File 411 has a different length: 661794
# File 436 has a different length: 661794
# File 437 has a different length: 661794
# File 438 has a different length: 661794
# File 439 has a different length: 661794
# File 440 has a different length: 661794
# File 441 has a different length: 661794
# File 442 has a different length: 661794
# File 443 has a different length: 661794
# File 444 has a different length: 661794
# File 445 has a different length: 661794
# File 446 has a different length: 661794
# File 447 has a different length: 661794
# File 448 has a different length: 661794
# File 449 has a different length: 661794
# File 450 has a different length: 661794
# File 451 has a different length: 661794
# File 452 has a different length: 661794
# File 453 has a different length: 661794
# File 454 has a different length: 661794
# File 455 has a different length: 661794
# File 456 has a different length: 661794
# File 457 has a different length: 661794
# File 458 has a different length: 661794
# File 459 has a different length: 661794
# File 460 has a different length: 661794
# File 461 has a different length: 661794
# File 462 has a different length: 661794
# File 463 has a different length: 661794
# File 464 has a different length: 661794
# File 465 has a different length: 661794
# File 466 has a different length: 661794
# File 467 has a different length: 661794
# File 468 has a different length: 661794
# File 469 has a different length: 661794
# File 470 has a different length: 661794
# File 471 has a different length: 661794
# File 472 has a different length: 661794
# File 473 has a different length: 661794
# File 474 has a different length: 661794
# File 475 has a different length: 661794
# File 500 has a different length: 661794
# File 501 has a different length: 665280
# File 502 has a different length: 661344
# File 503 has a different length: 661794
# File 504 has a different length: 661794
# File 505 has a different length: 661794
# File 506 has a different length: 661794
# File 507 has a different length: 661794
# File 508 has a different length: 661794
# File 509 has a different length: 661794
# File 510 has a different length: 661794
# File 511 has a different length: 661760
# File 512 has a different length: 661794
# File 513 has a different length: 661794
# File 514 has a different length: 661794
# File 515 has a different length: 661794
# File 516 has a different length: 661794
# File 517 has a different length: 670120
# File 518 has a different length: 661794
# File 519 has a different length: 661676
# File 520 has a different length: 661794
# File 521 has a different length: 661794
# File 522 has a different length: 661794
# File 523 has a different length: 661794
# File 524 has a different length: 669680
# File 525 has a different length: 663080
# File 526 has a different length: 661794
# File 527 has a different length: 672282
# File 528 has a different length: 661794
# File 529 has a different length: 661794
# File 530 has a different length: 661794
# File 531 has a different length: 661794
# File 532 has a different length: 661794
# File 533 has a different length: 661794
# File 534 has a different length: 661794
# File 535 has a different length: 661794
# File 536 has a different length: 661794
# File 537 has a different length: 661794
# File 538 has a different length: 661794
# File 539 has a different length: 661794
# File 540 has a different length: 661794
# File 541 has a different length: 661794
# File 542 has a different length: 661794
# File 543 has a different length: 661794
# File 544 has a different length: 661794
# File 545 has a different length: 661794
# File 546 has a different length: 661794
# File 547 has a different length: 661794
# File 548 has a different length: 661794
# File 549 has a different length: 661794
# File 550 has a different length: 661794
# File 551 has a different length: 661794
# File 552 has a different length: 661794
# File 553 has a different length: 661794
# File 554 has a different length: 661794
# File 555 has a different length: 661794
# File 556 has a different length: 661794
# File 557 has a different length: 661794
# File 558 has a different length: 661794
# File 559 has a different length: 661794
# File 560 has a different length: 661794
# File 561 has a different length: 661794
# File 562 has a different length: 661794
# File 563 has a different length: 661794
# File 564 has a different length: 661794
# File 565 has a different length: 661794
# File 566 has a different length: 661794
# File 567 has a different length: 661794
# File 568 has a different length: 661794
# File 569 has a different length: 661794
# File 570 has a different length: 661794
# File 571 has a different length: 661794
# File 572 has a different length: 661794
# File 573 has a different length: 661794
# File 574 has a different length: 661794
# File 575 has a different length: 661794
# File 576 has a different length: 661794
# File 577 has a different length: 661794
# File 578 has a different length: 661794
# File 579 has a different length: 661794
# File 580 has a different length: 661794
# File 581 has a different length: 661794
# File 582 has a different length: 661794
# File 583 has a different length: 661794
# File 584 has a different length: 661794
# File 585 has a different length: 661794
# File 586 has a different length: 661794
# File 587 has a different length: 661794
# File 588 has a different length: 661794
# File 589 has a different length: 661794
# File 590 has a different length: 661794
# File 591 has a different length: 661794
# File 592 has a different length: 661794
# File 593 has a different length: 661794
# File 594 has a different length: 661794
# File 595 has a different length: 661794
# File 596 has a different length: 661408
# File 597 has a different length: 663520
# File 598 has a different length: 661794
# File 599 has a different length: 661794
# File 600 has a different length: 661794
# File 601 has a different length: 661794
# File 602 has a different length: 661794
# File 603 has a different length: 661408
# File 604 has a different length: 661794
# File 605 has a different length: 661794
# File 606 has a different length: 661794
# File 607 has a different length: 661794
# File 608 has a different length: 661794
# File 609 has a different length: 661794
# File 610 has a different length: 661794
# File 611 has a different length: 661794
# File 612 has a different length: 661794
# File 613 has a different length: 661794
# File 614 has a different length: 661794
# File 615 has a different length: 661794
# File 616 has a different length: 661794
# File 617 has a different length: 661794
# File 618 has a different length: 661794
# File 619 has a different length: 661794
# File 620 has a different length: 661794
# File 621 has a different length: 661794
# File 622 has a different length: 661794
# File 623 has a different length: 661794
# File 624 has a different length: 661794
# File 625 has a different length: 661794
# File 626 has a different length: 661794
# File 627 has a different length: 661794
# File 628 has a different length: 661794
# File 629 has a different length: 661794
# File 630 has a different length: 661794
# File 631 has a different length: 661794
# File 632 has a different length: 661794
# File 633 has a different length: 661794
# File 634 has a different length: 661794
# File 635 has a different length: 661794
# File 636 has a different length: 661794
# File 637 has a different length: 661794
# File 638 has a different length: 661794
# File 639 has a different length: 661794
# File 640 has a different length: 661794
# File 641 has a different length: 661794
# File 642 has a different length: 661794
# File 643 has a different length: 661794
# File 644 has a different length: 661794
# File 645 has a different length: 661794
# File 646 has a different length: 661794
# File 647 has a different length: 661794
# File 648 has a different length: 661794
# File 649 has a different length: 661794
# File 650 has a different length: 661794
# File 651 has a different length: 661794
# File 652 has a different length: 661794
# File 653 has a different length: 661794
# File 654 has a different length: 661794
# File 655 has a different length: 661794
# File 656 has a different length: 661794
# File 657 has a different length: 661794
# File 658 has a different length: 661794
# File 659 has a different length: 661794
# File 660 has a different length: 661794
# File 661 has a different length: 661794
# File 662 has a different length: 661794
# File 663 has a different length: 661794
# File 664 has a different length: 661794
# File 665 has a different length: 661794
# File 666 has a different length: 661794
# File 667 has a different length: 661794
# File 668 has a different length: 661794
# File 669 has a different length: 661794
# File 670 has a different length: 661794
# File 671 has a different length: 661794
# File 672 has a different length: 661794
# File 673 has a different length: 661794
# File 674 has a different length: 661794
# File 675 has a different length: 661794
# File 676 has a different length: 661794
# File 677 has a different length: 661794
# File 678 has a different length: 661794
# File 679 has a different length: 661794
# File 680 has a different length: 661794
# File 681 has a different length: 661794
# File 682 has a different length: 661794
# File 683 has a different length: 661794
# File 684 has a different length: 661794
# File 685 has a different length: 661794
# File 686 has a different length: 661500
# File 687 has a different length: 661794
# File 688 has a different length: 670340
# File 689 has a different length: 661794
# File 690 has a different length: 661794
# File 691 has a different length: 667920
# File 692 has a different length: 661794
# File 693 has a different length: 661794
# File 694 has a different length: 661794
# File 695 has a different length: 661794
# File 696 has a different length: 661794
# File 697 has a different length: 661794
# File 698 has a different length: 669460
# File 699 has a different length: 661794
# File 700 has a different length: 661794
# File 701 has a different length: 675808
# File 702 has a different length: 675808
# File 703 has a different length: 661794
# File 704 has a different length: 661794
# File 705 has a different length: 668140
# File 706 has a different length: 661794
# File 707 has a different length: 661794
# File 708 has a different length: 667700
# File 709 has a different length: 661794
# File 710 has a different length: 661760
# File 711 has a different length: 661794
# File 712 has a different length: 661794
# File 713 has a different length: 661794
# File 714 has a different length: 661794
# File 715 has a different length: 661408
# File 716 has a different length: 664400
# File 717 has a different length: 665280
# File 718 has a different length: 660000
# File 719 has a different length: 669680
# File 720 has a different length: 661794
# File 721 has a different length: 675808
# File 722 has a different length: 661794
# File 723 has a different length: 661794
# File 724 has a different length: 661794
# File 725 has a different length: 661794
# File 726 has a different length: 661794
# File 727 has a different length: 661794
# File 728 has a different length: 675808
# File 729 has a different length: 661794
# File 730 has a different length: 661794
# File 731 has a different length: 675808
# File 732 has a different length: 661794
# File 733 has a different length: 661794
# File 735 has a different length: 661794
# File 736 has a different length: 675808
# File 737 has a different length: 661794
# File 738 has a different length: 661794
# File 739 has a different length: 661794
# File 740 has a different length: 661794
# File 741 has a different length: 661794
# File 742 has a different length: 661794
# File 743 has a different length: 661794
# File 744 has a different length: 661794
# File 745 has a different length: 661794
# File 746 has a different length: 675808
# File 747 has a different length: 661794
# File 749 has a different length: 661794
# File 750 has a different length: 661794
# File 751 has a different length: 661794
# File 752 has a different length: 661794
# File 754 has a different length: 661794
# File 755 has a different length: 675808
# File 756 has a different length: 661794
# File 757 has a different length: 661794
# File 758 has a different length: 661794
# File 759 has a different length: 661794
# File 760 has a different length: 661794
# File 761 has a different length: 661794
# File 763 has a different length: 661794
# File 764 has a different length: 661794
# File 765 has a different length: 661794
# File 766 has a different length: 661794
# File 768 has a different length: 661794
# File 769 has a different length: 661794
# File 771 has a different length: 661794
# File 772 has a different length: 661794
# File 773 has a different length: 661794
# File 774 has a different length: 661794
# File 775 has a different length: 661794
# File 776 has a different length: 661794
# File 777 has a different length: 661794
# File 778 has a different length: 661794
# File 779 has a different length: 661794
# File 781 has a different length: 661794
# File 782 has a different length: 661794
# File 784 has a different length: 661676
# File 785 has a different length: 661794
# File 788 has a different length: 661794
# File 789 has a different length: 669240
# File 790 has a different length: 661794
# File 792 has a different length: 675808
# File 793 has a different length: 675808
# File 795 has a different length: 661794
# File 797 has a different length: 661794
# File 798 has a different length: 661794
# File 800 has a different length: 661794
# File 801 has a different length: 661794
# File 802 has a different length: 661794
# File 803 has a different length: 661794
# File 804 has a different length: 661794
# File 805 has a different length: 661794
# File 806 has a different length: 661794
# File 807 has a different length: 661794
# File 808 has a different length: 661794
# File 809 has a different length: 661794
# File 810 has a different length: 661794
# File 811 has a different length: 661794
# File 812 has a different length: 661794
# File 813 has a different length: 661794
# File 814 has a different length: 661794
# File 815 has a different length: 661794
# File 816 has a different length: 661794
# File 817 has a different length: 661794
# File 818 has a different length: 661794
# File 819 has a different length: 661794
# File 820 has a different length: 661794
# File 821 has a different length: 661794
# File 822 has a different length: 661794
# File 823 has a different length: 661794
# File 824 has a different length: 661794
# File 825 has a different length: 663300
# File 826 has a different length: 661794
# File 827 has a different length: 661794
# File 828 has a different length: 661760
# File 829 has a different length: 661794
# File 830 has a different length: 661794
# File 831 has a different length: 661408
# File 832 has a different length: 669680
# File 833 has a different length: 661794
# File 834 has a different length: 661794
# File 835 has a different length: 668800
# File 836 has a different length: 661100
# File 837 has a different length: 661794
# File 838 has a different length: 666820
# File 839 has a different length: 661794
# File 840 has a different length: 661794
# File 841 has a different length: 661794
# File 842 has a different length: 661794
# File 843 has a different length: 661408
# File 844 has a different length: 663300
# File 845 has a different length: 661794
# File 846 has a different length: 661794
# File 847 has a different length: 661794
# File 848 has a different length: 661794
# File 849 has a different length: 663740
# File 850 has a different length: 661794
# File 851 has a different length: 661794
# File 852 has a different length: 661794
# File 853 has a different length: 661794
# File 854 has a different length: 661794
# File 855 has a different length: 661794
# File 856 has a different length: 661794
# File 857 has a different length: 661794
# File 858 has a different length: 661794
# File 859 has a different length: 661794
# File 860 has a different length: 661794
# File 861 has a different length: 661794
# File 862 has a different length: 661794
# File 863 has a different length: 661794
# File 864 has a different length: 661794
# File 865 has a different length: 661794
# File 866 has a different length: 661794
# File 867 has a different length: 661794
# File 868 has a different length: 661794
# File 869 has a different length: 661794
# File 870 has a different length: 661794
# File 871 has a different length: 661794
# File 872 has a different length: 661794
# File 873 has a different length: 661794
# File 874 has a different length: 661794
# File 875 has a different length: 661794
# File 876 has a different length: 661794
# File 877 has a different length: 661794
# File 878 has a different length: 661794
# File 879 has a different length: 661794
# File 880 has a different length: 661794
# File 881 has a different length: 661794
# File 882 has a different length: 661794
# File 883 has a different length: 661794
# File 884 has a different length: 661794
# File 885 has a different length: 661794
# File 886 has a different length: 661794
# File 887 has a different length: 661794
# File 888 has a different length: 661794
# File 889 has a different length: 661794
# File 890 has a different length: 661794
# File 891 has a different length: 661794
# File 892 has a different length: 661794
# File 893 has a different length: 661794
# File 894 has a different length: 661794
# File 895 has a different length: 661794
# File 896 has a different length: 661794
# File 897 has a different length: 661794
# File 898 has a different length: 661794
# File 899 has a different length: 661794
# File 900 has a different length: 661794
# File 901 has a different length: 661794
# File 902 has a different length: 661794
# File 903 has a different length: 661794
# File 904 has a different length: 661794
# File 905 has a different length: 661794
# File 906 has a different length: 661794
# File 907 has a different length: 661794
# File 908 has a different length: 661794
# File 909 has a different length: 661794
# File 910 has a different length: 661794
# File 911 has a different length: 661794
# File 912 has a different length: 661794
# File 913 has a different length: 661794
# File 914 has a different length: 661794
# File 915 has a different length: 661794
# File 916 has a different length: 661794
# File 917 has a different length: 661794
# File 918 has a different length: 661794
# File 919 has a different length: 661794
# File 920 has a different length: 661794
# File 921 has a different length: 666820
# File 922 has a different length: 661676
# File 923 has a different length: 661794
# File 924 has a different length: 661794
# File 925 has a different length: 661794
# File 926 has a different length: 661794
# File 927 has a different length: 661794
# File 928 has a different length: 661794
# File 929 has a different length: 661794
# File 930 has a different length: 661794
# File 931 has a different length: 669240
# File 932 has a different length: 661794
# File 933 has a different length: 661794
# File 934 has a different length: 661794
# File 935 has a different length: 661794
# File 936 has a different length: 661794
# File 937 has a different length: 667480
# File 938 has a different length: 661794
# File 939 has a different length: 661794
# File 940 has a different length: 661980
# File 941 has a different length: 661794
# File 942 has a different length: 661794
# File 943 has a different length: 672100
# File 945 has a different length: 661794
# File 946 has a different length: 661794
# File 947 has a different length: 661794
# File 948 has a different length: 661794
# File 949 has a different length: 661794
# File 950 has a different length: 661794
# File 951 has a different length: 661794
# File 952 has a different length: 661794
# File 953 has a different length: 661794
# File 954 has a different length: 661794
# File 955 has a different length: 661794
# File 956 has a different length: 661794
# File 957 has a different length: 661794
# File 958 has a different length: 661794
# File 959 has a different length: 661794
# File 960 has a different length: 665280
# File 961 has a different length: 661794
# File 962 has a different length: 661794
# File 963 has a different length: 665940
# File 964 has a different length: 661794
# File 965 has a different length: 661794
# File 966 has a different length: 661794
# File 967 has a different length: 661794
# File 968 has a different length: 661794
# File 969 has a different length: 661794
# File 970 has a different length: 661794
# File 971 has a different length: 661794
# File 972 has a different length: 661794
# File 973 has a different length: 661794
# File 974 has a different length: 661794
# File 975 has a different length: 661794
# File 976 has a different length: 661794
# File 977 has a different length: 661794
# File 978 has a different length: 669240
# File 979 has a different length: 661794
# File 980 has a different length: 661794
# File 981 has a different length: 661794
# File 982 has a different length: 661794
# File 983 has a different length: 661794
# File 984 has a different length: 661794
# File 985 has a different length: 661794
# File 986 has a different length: 661794
# File 987 has a different length: 661794
# File 988 has a different length: 661794
# File 989 has a different length: 661794
# File 990 has a different length: 661794
# File 991 has a different length: 661794
# File 992 has a different length: 661794
# File 993 has a different length: 661794
# File 994 has a different length: 661794
# File 995 has a different length: 661794
# File 996 has a different length: 661794
# File 997 has a different length: 661794
# File 998 has a different length: 661794
# File 999 has a different length: 661794

# %% [markdown]
# To ensure consistency we standardise the lengths of the audio by trunicating each file to that of the shortest one.

# %%
shortest_length = min(len(x) for x in X) #finding the shortest audio

X = [x[:shortest_length] for x in X] #slicing each file to match the length

# %% [markdown]
# Finally, Saving the processed lists into numpy files

# %%
np.save('X_Data.npy', X)
np.save('y_Genres.npy', y)        
np.save('file_names.npy', file_names)
